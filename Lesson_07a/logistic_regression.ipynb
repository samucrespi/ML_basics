# %%
import pandas as pd

df = pd.read_csv("insurance_data.csv")
df.shape
df.head(5)
df.describe()
# Out:
#              age  bought_insurance
# count  27.000000         27.000000
# mean   39.666667          0.518519
# std    15.745573          0.509175
# min    18.000000          0.000000
# 25%    25.000000          0.000000
# 50%    45.000000          1.000000
# 75%    54.500000          1.000000
# max    62.000000          1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(df.age,df.bought_insurance)

# %%
from sklearn.model_selection import train_test_split

X = df.age
y = df.bought_insurance

X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.8,random_state=42)

plt.scatter(X_train,y_train,label="train")
plt.scatter(X_test,y_test,label="test")
plt.legend()

# %%
# With one feature only it is better to use np.array
X_train = np.asarray(X_train).reshape(-1, 1)
y_train = np.asarray(y_train)
X_test = np.asarray(X_test).reshape(-1, 1)
y_test = np.asarray(y_test)

# %%
# Let's now do the logistic regression

from sklearn.linear_model import LogisticRegression
import numpy as np

mod = LogisticRegression()
mod.fit(X_train,y_train)
print(mod.predict(X_test))

print(mod.score(X_test,y_test))
# Out:
# [1 0 1 0 0 0]
# 1.0

# %%
# We can also see the probability

mod.predict_proba(X_test)
# Out:
# array([[0.05428681, 0.94571319],
#        [0.70555426, 0.29444574],
#        [0.06039343, 0.93960657],
#        [0.77085061, 0.22914939],
#        [0.84096546, 0.15903454],
#        [0.72848825, 0.27151175]])

# %%
plt.scatter(X_train,y_train,label="train")
plt.scatter(X_test,y_test,label="test")
plt.legend()

x_mod = np.linspace(15,70,1000).reshape(-1, 1)
y_mod = [val[1] for val in mod.predict_proba(x_mod)]
plt.plot(x_mod,y_mod)
